# %%
import PIL
#PIL is python Imaging library .It adds image processing capabalities to interpreter

# %%
from PIL import ImageColor
#The ImageColor module contains color tables and converters from CSS3-style color specifiers to RGBA tuples.
#Every color is represented by values of Red,Green,Blue and Alpha-Transpery values ranging from 0-255

# %%
ImageColor.getcolor("red","RGBA")
# Out:
# (255, 0, 0, 255)

# %%
ImageColor.getcolor("pink","RGBA")
# Out:
# (255, 192, 203, 255)

# %%
ImageColor.getcolor("grey","RGBA")
# Out:
# (128, 128, 128, 255)

# %%
from PIL import Image

# %%
Vijay=Image.open("ARJUN REDDY.jpg")

# %%
Vijay
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x297 at 0x1FF26BA68D0>

# %%
Vijay.size
# Out:
# (200, 297)

# %%
Vijay.format
# Out:
# 'JPEG'

# %%
Vijay.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
im=Image.new("RGBA",(200,200),"black")
im.save("black.jpg")

# %%
im
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x1FF269AD7B8>

# %%
Vijayc=Vijay.crop((20,20,200,200))
Vijayc.save("Vijaycrop.jpg")
#crop function takes boxtupple as input # box tuple are coordinates of top-left corner and bottom ri8 corner

# %%
Vijayc
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x1FF269AD860>

# %%
Vijayc.save("Vijayc.jpg")

# %%
poster=Image.open("ArjunReddyposter1.png")

# %%
poster
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=455x303 at 0x1FF269D5C18>

# %%
poster=poster.resize((135,100))
poster
# Out:
# <PIL.Image.Image image mode=RGB size=135x100 at 0x1FF269ADBE0>

# %%
VijayCopy=Vijay.copy()
VijayCopy.paste(poster,(20,190))
VijayCopy.save("pasted.png")
VijayCopy
# Out:
# <PIL.Image.Image image mode=RGB size=200x297 at 0x1FF269ADEB8>

# %%
VijayCopy.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=200x297 at 0x1FF269ADC50>

# %%
VijayCopy.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=200x297 at 0x1FF269ADAC8>

# %%
VijayCopy.rotate(18)
# Out:
# <PIL.Image.Image image mode=RGB size=200x297 at 0x1FF269AD8D0>

# %%
VijayCopy.rotate(18,expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=282x345 at 0x1FF269ADBA8>

# %%
VijayCopy.transpose(Image.TRANSPOSE)
# Out:
# <PIL.Image.Image image mode=RGB size=297x200 at 0x1FF269ADC88>

# %%
Image.open("pasted.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x297 at 0x1FF269AE4E0>
